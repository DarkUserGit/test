# %% [markdown]
# <link rel="stylesheet" href="styles/theme_style.css">
# ![OpenSignals_logo](images/OS_logo_title.png)
#
# Hello, be welcome to the **<span style="color:#009EE3">OpenSignals Tools</span>** environment !!!
#
# This page is intended to make available to the users of *Plux Wireless Biosignals* systems, such as **bitalino** or **biosignalsplux**, a set of **<span class="color5">Jupyter Notebooks</span>**.
#
# In these informative and interactive resources, it is explained and demonstrated how some processing operations can be done in **<span class="color1">Python</span>**.
# For example, it is explained how the acquired signals can be loaded and ploted.
# Additionally, are presented some detection methods of ECG R peaks and muscular activation periods on EMG data.
#
# Many of the processing operations described in **<span class="color5">Jupyter Notebooks</span>** are incorporated in *opensignalstools* library.
#
# This **<span class="color1">Python</span>** package contains functions specially defined to answer the needs of the **<span style="color:#009EE3">OpenSignals</span>** users.
#
# For an integrated, automatic and broad processing experience, using multiple processing operations simultaneously, the user can purchase **<span style="color:#009EE3">OpenSignals</span>** plugins.
#
# <div class="title"><h2 class="color11"> Available Notebooks </h2></div>
#
# <table width="100%">
#     <tr class="border_cell_bottom_black">
#         <td width="20%" class="center_cell"> Category </td>
#         <td width="60%" class="center_cell"> Functionality </td>
#         <td width="20%" class="center_cell"> Notebook </td>
#     </tr>
#     <tr>
#         <td rowspan="2" class="center_cell open_cell_border_2"><span style="float:center"><img src="images/icons/Acquisition.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color2"> Acquire </span></td>
#         <td class="center_cell open_cell_light"> Problems of a smaller sampling frequency (subsampling) </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Acquire/Subsampling.ipynb) </td>
#     </tr>
#     <tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_light"> Resolution - The difference between smooth and abrupt variations </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Acquire/Resolution.ipynb) </td>
#     </tr>
#     <tr>
#         <td rowspan="2" class="center_cell open_cell_border_1"><span style="float:center"><img src="images/icons/Open.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color1"> Open </span></td>
#         <!--td class="center_cell color1_cell round_cell_left"> Open </td-->
#         <td class="center_cell open_cell_light"> Load the acquired data from .h5 file </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Open/Open_h5.ipynb)</td>
#     </tr>
#     <tr class="border_cell_bottom_white">
#         <!--td style="background-color:white"></td-->
#         <td class="center_cell open_cell_light"> Load the acquired data from .txt file </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Open/Open_txt.ipynb) </td>
#     </tr>
#     <!--tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_light"> Load the acquired data from .edf file </td>
#         <td class="center_cell"> --- </td>
#     </tr-->
#     <tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_border_3"> <span style="float:center"><img src="images/icons/Visualise.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color3"> Visualise </span></td>
#         <td class="center_cell open_cell_light"> Plotting of Acquired Data using Bokeh </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Visualise/Plot_Acquired_Data_Single.ipynb) </td>
#     </tr>
#     <tr>
#         <td rowspan="4" class="center_cell open_cell_border_4"> <span style="float:center"><img src="images/icons/Process.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color4"> Process </span></td>
#         <td class="center_cell open_cell_light"> Digital Filtering - A Fundamental Pre-Processing Step</td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Process/Digital_Filtering.ipynb) </td>
#     </tr>
#     <tr>
#         <td class="center_cell open_cell_light"> Fatigue Evaluation - Evolution of Median Power Frequency </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Process/Fatigue_Evaluation_Median_Freq.ipynb) </td>
#     </tr>
#     <tr>
#         <td class="center_cell open_cell_light"> Generation of Tachogram (ECG) </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Process/Tachogram.ipynb) </td>
#     </tr>
#     <tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_light"> Generation of Poincaré Plot from ECG Analysis </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Process/Poincare_Plot.ipynb) </td>
#     </tr>
#     <tr>
#         <td rowspan="3" class="center_cell open_cell_border_5"> <span style="float:center"><img src="images/icons/Detect.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color5"> Detect </span></td>
#         <td class="center_cell open_cell_light"> Event Detection - R Peaks (ECG) </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Detect/R_Peaks.ipynb) </td>
#     </tr>
#     <tr>
#         <td class="center_cell open_cell_light"> Event Detection - Muscular Activations (EMG) </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Detect/Detect_Bursts.ipynb) </td>
#     </tr>
#     <tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_light"> Detection of outliers </td>
#         <td class="center_cell"> --- </td>
#     </tr>
#     <tr>
#         <td rowspan="2" class="center_cell open_cell_border_6"> <span style="float:center"><img src="images/icons/Extract.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color6"> Extract </span></td>
#         <td class="center_cell open_cell_light"> ECG Analysis - Heart Rate Variability Parameters  </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Extract/HRV_Parameters.ipynb) </td>
#     </tr>
#     <tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_light"> EMG Analysis - Time and Frequency Parameters </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Extract/EMG_Parameters.ipynb) </td>
#     </tr>
#     <tr class="border_cell_bottom_white">
#         <td class="center_cell open_cell_border_7"> <span style="float:center"><img src="images/icons/Decide.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color7"> Decide </span></td>
#         <td class="center_cell open_cell_light"> Automatic identification of signal type </td>
#         <td class="center_cell"> --- </td>
#     </tr>
#     <tr>
#         <td rowspan="2" class="center_cell open_cell_border_8"> <span style="float:center"><img src="images/icons/Explain.png" class="icon" style="vertical-align:middle"></span> <span style="float:center" class="color8"> Explain </span></td>
#         <td class="center_cell open_cell_light"> Unit Conversion (bits to mV) </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Explain/bit_to_mV.ipynb) </td>
#     </tr>
#     <tr>
#         <td class="center_cell open_cell_light"> Generation of a time axis (conversion of samples into seconds) </td>
#         <td class="center_cell"> [<div class="file_icon"></div>](Categories/Explain/samples_to_time.ipynb) </td>
#     </tr>
# </table>

# %% [markdown]
# <span class="color6">**Auxiliary Code Segment (should not be replicated by the user)**</span>

# %%
from opensignalstools.__notebook_support__ import cssStyleApply
cssStyleApply()
# Out:
# .................... CSS Style Applied to Jupyter Notebook .........................
# <style>
# @import url(https://fonts.googleapis.com/css?family=Cuprum|Lato);
# body {
# font-family: 'Cuprum' !important;
# font-size: 12pt !important;
# line-height: 1 !important;
# font-weight: 400 !important;
# color: #58585A !important;
# text-align: justify !important;
# text-justify: inter-word !important;
# background-color: rgba(162,162,162,0.7) !important;
# }
# /*
# #notebook-container {
# -webkit-box-shadow: none;
# box-shadow: none;
# }
# .rendered_html h1 { font-size: 4rem !important;  }
# .rendered_html h2 { font-size: 3rem !important; }
# .rendered_html h3 { font-size: 2.5rem !important; }
# .rendered_html h4 { font-size: 2rem !important; }
# .rendered_html h5 { font-size: 1.5rem !important; }
# .rendered_html h6 { font-size: 1.5rem !important; }
# .rendered_html h1,
# .rendered_html h2,
# .rendered_html h3,
# .rendered_html h4,
# .rendered_html h5,
# .rendered_html h6 {
# ...
